# %% [markdown]
# <h1 style="color:red; font-family: 'Helvetica Neue', sans-serif; font-size:40px; text-align: center; font-weight:bold; font-style:italic">Problem Statement</h1>

# %% [markdown]
# # Business Case:
#
# FicZon Inc is an IT solution provider with products ranging from on-
# premises products to SAAS (Software-as-a-Service ) based solutions. FicZon major leads
#
# generation channel is digital and through their website.
# FicZon business is majorly dependent on the sales force
# effectiveness. As the market is maturing and more new competitors
# entering the market, FicZon is experiencing the dip in sales.
# Effective sales is dependent on lead quality and as of now, this is
# based on manual categorization and highly depended on sales staff.
# Though there is a quality process, which continuously updates the
# lead categorization, it’s value is in for post analysis, rather than
# conversation.
# FicZon wants to explore Machine Learning to pre-categorize the lead
# quality and as result, expecting significant increase in sales
# effectiveness.

# %% [raw]
# Database details:
# DB Name: project_sales
# Table Name: data
# Host: 18.136.157.135
# Port: 3306
# Username: dm_team2
# Password: DM!$Team&27@9!20!

# %% [markdown]
# <h1 style="font-family:verdana; color:#228B22; background-color:#FFFFE0;text-align: center;">Domain Analysis</h1>

# %% [raw]
# fincoz is a softever base company thiscompany make a softervers for the customers. In this compition world the company wants which sales department doing well and which sales deparment not giving more buisness with the help of mashine learning i.e company ceo gives theis project, With the help of given data we want to know which sales team giving high business and how to enchance buiseness.

# %% [markdown]
# Continuously monitor the performance of the ML model, gather feedback from the sales team, and refine the model based on real-world outcomes.
#
# In conclusion, FicZon Inc has the opportunity to enhance their sales force effectiveness by implementing Machine Learning to predict lead quality. This could lead to increased sales, better resource allocation, and improved overall performance in a competitive market. However, careful planning, data quality assurance, and ongoing monitoring are critical to the success of this initiative.

# %% [markdown]
# # <font color='tomato'>Attribution Information:</font>
#
# In Attribution Info we sotored info of our given data in descriptive like in data only give feature this feature how to use and what is the use of this feature for this purpose we create the attribution info.
# 'Created' Column:
# Analyze the 'Created' column to understand the timing of customer interactions and conversions. You can create time-based visualizations, such as line charts, to see trends and patterns in customer engagement over time.
#
# 'Product_ID' Column:
# Explore the 'Product_ID' column to identify which products are most frequently associated with conversions. This can help you understand the product preferences of your customers and tailor your marketing strategies accordingly.
#
# 'Source' Column:
# Analyze the 'Source' column to determine where your leads and conversions are originating from. Visualize the distribution of sources using bar charts to identify which sources are driving the most valuable conversions.
#
# 'Mobile' and 'EMAIL' Columns:
# These columns likely contain contact information. Analyze the distribution of mobile numbers and email addresses among your conversions. You could also look at whether conversions from one of these contact methods tend to have higher or lower value.
#
# 'Sales_Agent' Column:
# Explore the 'Sales_Agent' column to understand the role of each sales agent in driving conversions. Visualize the performance of different sales agents using bar charts or other relevant graphs.
#
# 'Location' Column:
# Analyze the 'Location' column to identify geographical patterns in your conversions. You can use maps or bar charts to visualize which locations are contributing the most to your conversions.
#
# 'Delivery_Mode' Column:
# Explore the 'Delivery_Mode' column to understand the preferred delivery methods chosen by customers who convert. Visualize the distribution of delivery modes to see if there's a preferred mode among converters.
#
# 'Status' Column:
# Analyze the 'Status' column to determine the outcome of each lead or interaction.

# %% [markdown]
# <h1 style="font-family:verdana; color:#228B22; background-color:#FFFFE0;text-align: center;">Installing Modules</h1>

# %% [raw]
# !pip install pymysql

# %% [raw]
# !pip install pandas sqlalchemy

# %% [raw]
# !pip install mysql-connector-python

# %%
# Importing basic libraries/Packages.
import os # automatically it will avilable it access to use all system inour pc opreting system.
import numpy as np # data manupulation tool.
import pandas as pd # data fream tool.
import seaborn as sns # visualisation tool.
import matplotlib.pyplot as plt # visualisation tool.
import warnings
warnings.filterwarnings('ignore')
from sqlalchemy import create_engine # for loading sql data from server.

# %%
import urllib.parse

# Database connection details
db_name = 'project_sales'
host = '18.136.157.135'
port = 3306
username = 'dm_team2'
password = 'DM!$Team&27@9!20!'  # Replace with the actual password

# URL encode the password
encoded_password = urllib.parse.quote_plus(password)

# Create a database connection URL
db_url = f'mysql+mysqlconnector://{username}:{encoded_password}@{host}:{port}/{db_name}'

# %%
import pandas as pd
from sqlalchemy import create_engine

# Create an SQLAlchemy engine
engine = create_engine(db_url)

# SQL query to fetch data from the 'data' table
query = 'SELECT * FROM data'

# Load data into a pandas DataFrame
data = pd.read_sql(query, engine)

# %%
data.head()  # Display the first few rows of the DataFrame
# Out:
#             Created Product_ID   Source      Mobile               EMAIL  \
# 0  14-11-2018 10:05             Website  984XXXXXXX  aXXXXXXX@gmail.com
# 1  14-11-2018 09:22             Website     XXXXXXX             #VALUE!
# 2  14-11-2018 09:21             Website     XXXXXXX  dXXXXXXX@yahoo.com
# 3  14-11-2018 08:46             Website     XXXXXXX  wXXXXXXX@gmail.com
# 4  14-11-2018 07:34             Website     XXXXXXX  cXXXXXXX@gmail.com
#
#       Sales_Agent Location Delivery_Mode Status
# 0  Sales-Agent-11                 Mode-5   Open
# 1  Sales-Agent-10                 Mode-5   Open
# 2  Sales-Agent-10                 Mode-5   Open
# 3  Sales-Agent-10                 Mode-5   Open
# 4  Sales-Agent-10                 Mode-5   Open

# %% [markdown]
# data.shape

# %%
data.columns
# Out:
# Index(['Created', 'Product_ID', 'Source', 'Mobile', 'EMAIL', 'Sales_Agent',
#        'Location', 'Delivery_Mode', 'Status'],
#       dtype='object')

# %%
data.head()
# Out:
#             Created Product_ID   Source      Mobile               EMAIL  \
# 0  14-11-2018 10:05             Website  984XXXXXXX  aXXXXXXX@gmail.com
# 1  14-11-2018 09:22             Website     XXXXXXX             #VALUE!
# 2  14-11-2018 09:21             Website     XXXXXXX  dXXXXXXX@yahoo.com
# 3  14-11-2018 08:46             Website     XXXXXXX  wXXXXXXX@gmail.com
# 4  14-11-2018 07:34             Website     XXXXXXX  cXXXXXXX@gmail.com
#
#       Sales_Agent Location Delivery_Mode Status
# 0  Sales-Agent-11                 Mode-5   Open
# 1  Sales-Agent-10                 Mode-5   Open
# 2  Sales-Agent-10                 Mode-5   Open
# 3  Sales-Agent-10                 Mode-5   Open
# 4  Sales-Agent-10                 Mode-5   Open

# %%
data.tail()
# Out:
#                Created Product_ID            Source Mobile  \
# 7417  28-04-2018 09:45          9              Call
# 7418  28-04-2018 09:43         15              Call
# 7419  28-04-2018 09:20          5  Live Chat-Direct
# 7420  28-04-2018 08:04         21          CRM form
# 7421  28-04-2018 07:54         25           Website
#
#                    EMAIL     Sales_Agent         Location Delivery_Mode  \
# 7417  aXXXXXXX@gmail.com   Sales-Agent-6           Mumbai        Mode-4
# 7418             #VALUE!  Sales-Agent-12  Other Locations        Mode-5
# 7419  sXXXXXXX@gmail.com  Sales-Agent-11        Bangalore        Mode-1
# 7420  YXXXXXXX@gmail.com   Sales-Agent-4  Other Locations        Mode-1
# 7421  cXXXXXXX@gmail.com   Sales-Agent-3          Chennai        Mode-1
#
#               Status
# 7417            LOST
# 7418            LOST
# 7419  Not Responding
# 7420    Just Enquiry
# 7421       CONVERTED

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7422 entries, 0 to 7421
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Created        7422 non-null   object
#  1   Product_ID     7422 non-null   object
#  2   Source         7422 non-null   object
#  3   Mobile         7422 non-null   object
#  4   EMAIL          7422 non-null   object
#  5   Sales_Agent    7422 non-null   object
#  6   Location       7422 non-null   object
#  7   Delivery_Mode  7422 non-null   object
#  8   Status         7422 non-null   object
# dtypes: object(9)
# memory usage: 522.0+ KB

# %%
data.describe(include='O') # In this data set data contain only object type i.e showing only cat val.
# Out:
#                  Created Product_ID Source Mobile    EMAIL    Sales_Agent  \
# count               7422       7422   7422   7422     7422           7422
# unique              6752         30     26    487      883             13
# top     26-09-2018 11:30         18   Call         #VALUE!  Sales-Agent-4
# freq                   4       1711   2547   1810     1701           1500
#
#                Location Delivery_Mode     Status
# count              7422          7422       7422
# unique               18             5         11
# top     Other Locations        Mode-5  Junk Lead
# freq               2500          2975       1536

# %% [raw]
# Insights:- with the analysis of data basic cheak get following insights from data.
#     1) In this dataset contain 7422 data points and 9 feature which data type are object.
#     2) In this data set any null values are not present
#     3) found 2 buplicate values and dropped it.
#     4) In this data in product Id column 18 id present 1711 data points
#     5) In source top most feature showing call with contain 2547 data points in 26 unique feature       will be presentd.
#     6) IN this data set 2 features are not showing any much importace in this data set which is          mobile and email so we can drop it
#     7) Sales agent column is imp in this 13 unique values presented which shows diff sales agent      in this 13 agency top most is 4 which showing 1500 data points
#     8)location in this data set showing diff loc top most showing other location but banglore           will be 1st one and 2nd is chainnai and 3 is hyd.
#     9)In top most showing 5 delivery mode
#     10) in staus we have to convert it into god bad like this but now showing top most is juck           lead
#     11_) In status showing customer whether buy our softerver or not and types of customer.

# %%
data.isnull().sum() # showing null vaues
# Out:
# Created          0
# Product_ID       0
# Source           0
# Mobile           0
# EMAIL            0
# Sales_Agent      0
# Location         0
# Delivery_Mode    0
# Status           0
# dtype: int64

# %%
data.isna().sum()# showing nan values.
# Out:
# Created          0
# Product_ID       0
# Source           0
# Mobile           0
# EMAIL            0
# Sales_Agent      0
# Location         0
# Delivery_Mode    0
# Status           0
# dtype: int64

# %%
data['Created'].unique
# Out:
# <bound method Series.unique of 0       14-11-2018 10:05
# 1       14-11-2018 09:22
# 2       14-11-2018 09:21
# 3       14-11-2018 08:46
# 4       14-11-2018 07:34
#               ...
# 7417    28-04-2018 09:45
# 7418    28-04-2018 09:43
# 7419    28-04-2018 09:20
# 7420    28-04-2018 08:04
# 7421    28-04-2018 07:54
# Name: Created, Length: 7422, dtype: object>

# %%
data.value_counts('Source')
# Out:
# Source
# Call                             2547
# Live Chat-Direct                 1834
# Website                          1594
# Live Chat-Google Organic          274
# Live Chat -PPC                    249
# Live Chat-Blog                    237
# Customer Referral                 180
# US Website                        137
# Just Dial                          56
# Existing Client                    51
# Live Chat-CPC                      50
# Personal Contact                   50
# By Recommendation                  32
# CRM form                           23
# Existing Customer                  22
# Live Chat-Google Ads               21
# Campaign                           19
#                                    17
# E-mail Campaign                    12
# Live Chat-Adwords Remarketing       7
# Live Chat-Quora                     2
# Live Chat-Youtube                   2
# Other                               2
# SMS Campaign                        2
# ...

# %%
data.value_counts('Sales_Agent')
# Out:
# Sales_Agent
# Sales-Agent-4     1500
# Sales-Agent-11    1420
# Sales-Agent-5     1190
# Sales-Agent-9      879
# Sales-Agent-3      781
# Sales-Agent-7      736
# Sales-Agent-2      389
# Sales-Agent-12     269
# Sales-Agent-6      114
# Sales-Agent-8       68
# Sales-Agent-10      49
#                     23
# Sales-Agent-1        4
# dtype: int64

# %%
data.value_counts('Location')
# Out:
# Location
# Other Locations    2500
# Bangalore          2084
# Chennai             909
# Hyderabad           528
# Delhi               471
# Mumbai              402
# Pune                142
# UAE                  79
#                      58
# Trivandrum           58
# Kolkata              55
# USA                  45
# UK                   41
# AUSTRALIA            25
# Singapore            17
# Malaysia              4
# EUROPE                3
# Howrah                1
# dtype: int64

# %%
data.value_counts('Delivery_Mode')
# Out:
# Delivery_Mode
# Mode-5    2975
# Mode-1    2627
# Mode-3    1688
# Mode-4     121
# Mode-2      11
# dtype: int64

# %%
data.value_counts('Status')
# Out:
# Status
# Junk Lead               1536
# Not Responding          1129
# CONVERTED                834
# Just Enquiry             760
# Potential                708
# Long Term                646
# In Progress Positive     643
# In Progress Negative     626
# LOST                     440
# Open                      82
# converted                 18
# dtype: int64

# %%
data.drop_duplicates(inplace=True)

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h1 style="font-family:verdana; color:#228B22; background-color:#FFFFE0;text-align: center;">Exploratory Data Analysis</h1>

# %%
# first we have clean data here only becoz in this data 'mobile','email' nothing showing any valuable information.
data=data.drop(columns=['Mobile','EMAIL','Created'])

# %%
data.head(3) # to cheak columns are droped o not
# Out:
#   Product_ID   Source     Sales_Agent Location Delivery_Mode Status
# 0             Website  Sales-Agent-11                 Mode-5   Open
# 1             Website  Sales-Agent-10                 Mode-5   Open
# 2             Website  Sales-Agent-10                 Mode-5   Open

# %% [markdown]
# ### <font color='tomato'>univariate analysis:</font>

# %%
import sweetviz as sv
sv.analyze(data).show_html()
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report SWEETVIZ_REPORT.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in data:
    if plotnumber<=10:
        ax=plt.subplot(5,2,plotnumber)
        sns.countplot(data[column])
        plt.xlabel(column,fontsize=20)
        plt.ylabel('count',fontsize=20)
        plt.xticks(rotation='vertical')
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Insights from univarite analysis :-
# - In product Id 18 product sell most showing in first graph.
# - source plot showing the contact of customer which shows most of the customer user to call enquirey
# - Sales agent showign the most of the selling 4 type of sells agent 20 % cover .
# - most of clint or customer from enquiry from benglore 27% , chennai 13% and hydrabad 8%.
# - in module 5 40% is the most of delivey mode
# - resone of customer enquiry showing top most is juck lead 22-25% data contain around something.
# -

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in data:
    if plotnumber<=10:
        ax=plt.subplot(5,2,plotnumber)
        sns.histplot(data[column],kde=True)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('count',fontsize=20)
        plt.xticks(rotation='vertical')
    plotnumber+=1
plt.tight_layout()

# %%
sns.histplot(x=data.Status,kde=True,data=data)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# <h1 style="font-family:verdana; color:#228B22; background-color:#FFFFE0;text-align: center;">Data Preprocessing</h1>
#
# we are doning first data preprocessing bcoz data will be not in certain format to do bivarite analysis and modle creation after data preprocessing we do both of the things.

# %%
data.head()
# Out:
#   Product_ID   Source     Sales_Agent Location Delivery_Mode Status
# 0             Website  Sales-Agent-11                 Mode-5   Open
# 1             Website  Sales-Agent-10                 Mode-5   Open
# 2             Website  Sales-Agent-10                 Mode-5   Open
# 3             Website  Sales-Agent-10                 Mode-5   Open
# 4             Website  Sales-Agent-10                 Mode-5   Open

# %%
data.value_counts('Source')
# Out:
# Source
# Call                             2547
# Live Chat-Direct                 1834
# Website                          1592
# Live Chat-Google Organic          274
# Live Chat -PPC                    249
# Live Chat-Blog                    237
# Customer Referral                 180
# US Website                        137
# Just Dial                          56
# Existing Client                    51
# Live Chat-CPC                      50
# Personal Contact                   50
# By Recommendation                  32
# CRM form                           23
# Existing Customer                  22
# Live Chat-Google Ads               21
# Campaign                           19
#                                    17
# E-mail Campaign                    12
# Live Chat-Adwords Remarketing       7
# Live Chat-Quora                     2
# Live Chat-Youtube                   2
# Other                               2
# SMS Campaign                        2
# ...

# %%
# In this feature there are in one catogory present sub types so we converted in to one main type i.e way is easy to understand. 
data.Source.replace(['Live Chat-Direct','Live Chat-Google Organic','Live Chat -PPC','Live Chat-Blog','Live Chat-Quora',
                    'Live Chat-CPC','Live Chat-Google Ads','Live Chat-Adwords Remarketing','Live Chat-Youtube',
                    'Live Chat-Justdial'],'live chat',inplace=True)
data.Source.replace(['Existing Client','CRM form','Personal Contact'],'Existing Customer',inplace=True)
data.Source.replace('By Recommendation','Customer Referral',inplace=True)
data.Source.replace(['US Website','Just Dial'],'Website',inplace=True)
data.Source.replace(['E-mail Campaign','SMS Campaign','E-Mail Message','Other'],'Campaign',inplace=True)

# %%
data.Source.value_counts() # converted into 5 main catogory.
# Out:
# live chat            2677
# Call                 2547
# Website              1785
# Customer Referral     212
# Existing Customer     146
# Campaign               36
#                        17
# Name: Source, dtype: int64

# %%
data.Location.value_counts().unique()
# Out:
# array([2500, 2084,  909,  528,  471,  402,  142,   79,   58,   56,   55,
#          45,   41,   25,   17,    4,    3,    1], dtype=int64)

# %%
# at every data if their are '' not any values persent and located like '' this then this is corrupted data we drop it
data.replace('',np.nan,inplace=True) # empty values replacing with Nan
data.dropna(inplace=True)
data.reset_index(inplace=True,drop=True) # droping nan values
data.shape
# Out:
# (7328, 6)

# %%
data.Status.value_counts()
# Out:
# Junk Lead               1532
# Not Responding          1119
# CONVERTED                834
# Just Enquiry             751
# Potential                705
# Long Term                644
# In Progress Positive     642
# In Progress Negative     625
# LOST                     439
# Open                      19
# converted                 18
# Name: Status, dtype: int64

# %% [markdown]
# **IN This data type our target feature is Satus so in this feature lots of customer types will present our machine not work well i.e we do main group like good customer , bad customer**

# %%
data.Status.value_counts()
# Out:
# Junk Lead               1532
# Not Responding          1119
# CONVERTED                834
# Just Enquiry             751
# Potential                705
# Long Term                644
# In Progress Positive     642
# In Progress Negative     625
# LOST                     439
# Open                      19
# converted                 18
# Name: Status, dtype: int64

# %%
data.Status.replace(['CONVERTED','Open','LOST','In Progress Negative','In Progress Positive','Long Term',
                    'Potential','Long Term','Just Enquiry','converted'],'Good',inplace=True)

# %%
data.Status.replace(['Not Responding','Junk Lead'],
                   'bad',inplace=True)

# %%
data.Status.value_counts()
# Out:
# Good    4677
# bad     2651
# Name: Status, dtype: int64

# %%
data.head()
# Out:
#   Product_ID     Source     Sales_Agent         Location Delivery_Mode Status
# 0          9  live chat   Sales-Agent-3        Bangalore        Mode-1   Good
# 1         19       Call   Sales-Agent-4  Other Locations        Mode-5   Good
# 2         18    Website  Sales-Agent-11       Trivandrum        Mode-1   Good
# 3         15    Website   Sales-Agent-7        Hyderabad        Mode-1    bad
# 4         18       Call   Sales-Agent-7        Bangalore        Mode-1   Good

# %% [raw]
# data.Status.replace(['LOST','Just Enquiry','Not Responding','Junk Lead'],'cold_lead',inplace=True)
# data.Status.replace(['Open','Long Term','Potential','In Progress Positive','In Progress Negative'],'warm_lead',inplace=True)
# data.Status.replace(['converted','Long Term','CONVERTED'],'hot_lead',inplace=True)

# %% [markdown]
# # <font color='tomato'>Encoding:</font>
#
# our data clean done now we are doing endoing teq in this teq cat value converted into num values. machine will undersatnd only num values

# %%
data['Sales_Agent'].unique() # this is also convert into numericatl data bcoz machine will not understand any name only undersatnd numerical values
# Out:
# array(['Sales-Agent-3', 'Sales-Agent-4', 'Sales-Agent-11',
#        'Sales-Agent-7', 'Sales-Agent-9', 'Sales-Agent-8', 'Sales-Agent-5',
#        'Sales-Agent-2', 'Sales-Agent-12', 'Sales-Agent-10',
#        'Sales-Agent-6'], dtype=object)

# %%
data.value_counts('Location') # this column aslo convert into numerical data using lable encoding.
# Out:
# Location
# Other Locations    2481
# Bangalore          2079
# Chennai             907
# Hyderabad           527
# Delhi               470
# Mumbai              399
# Pune                139
# UAE                  77
# Trivandrum           58
# Kolkata              55
# USA                  45
# UK                   41
# AUSTRALIA            25
# Singapore            17
# Malaysia              4
# EUROPE                3
# Howrah                1
# dtype: int64

# %%
data.Location.replace( ['UAE','USA','UK','AUSTRALIA','Singapore','Malaysia','EUROPE','Howrah'],'Foreign_Locations',inplace=True)

# %%
data.value_counts('Delivery_Mode')
# Out:
# Delivery_Mode
# Mode-5    2903
# Mode-1    2614
# Mode-3    1681
# Mode-4     120
# Mode-2      10
# dtype: int64

# %%
data.Status.value_counts()
# Out:
# Good    4677
# bad     2651
# Name: Status, dtype: int64

# %%
data.head(2)
# Out:
#   Product_ID     Source    Sales_Agent         Location Delivery_Mode Status
# 0          9  live chat  Sales-Agent-3        Bangalore        Mode-1   Good
# 1         19       Call  Sales-Agent-4  Other Locations        Mode-5   Good

# %%
# importing somte teqnique
from sklearn.preprocessing import LabelEncoder # importing package from sklearn
lr=LabelEncoder()# object creation

# %%
# converting data cat to num using label encoding teq.
data.Source=lr.fit_transform(data.Source)
data.Sales_Agent=lr.fit_transform(data.Sales_Agent)
data.Location=lr.fit_transform(data.Location)
data.Delivery_Mode=lr.fit_transform(data.Delivery_Mode)
#data.Status=lr.fit_transform(data.Status)

# %%
data.Status = data.Status.map({"Good":1, "bad":0})

# %%
data.Status.value_counts()
# Out:
# 1    4677
# 0    2651
# Name: Status, dtype: int64

# %%
data.head(3) # data converted into num
# Out:
#   Product_ID  Source  Sales_Agent  Location  Delivery_Mode  Status
# 0          9       5            4         0              0       1
# 1         19       0            5         7              4       1
# 2         18       4            1         9              0       1

# %% [markdown]
# Now we are redy to create model.

# %%
# spliting data dependent and independent features
x=data.iloc[:,:-1]#dependent
y=data.Status#independent features

# %%
x
# Out:
#      Product_ID  Source  Sales_Agent  Location  Delivery_Mode
# 0             9       5            4         0              0
# 1            19       0            5         7              4
# 2            18       4            1         9              0
# 3            15       4            8         4              0
# 4            18       0            8         0              0
# ...         ...     ...          ...       ...            ...
# 7323          9       0            7         6              3
# 7324         15       0            2         7              4
# 7325          5       5            1         0              0
# 7326         21       3            5         7              0
# 7327         25       4            4         1              0
#
# [7328 rows x 5 columns]

# %% [markdown]
# # <font color='tomato'>Bivariate Analysis:</font>

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for column in data:
    if plotnumber<=10:
        ax=plt.subplot(5,2,plotnumber)
        sns.countplot(data[column],hue=data.Status)
        plt.xlabel(column,fontsize=20)
        plt.ylabel('count',fontsize=20)
        plt.xticks(rotation='vertical')
    plotnumber+=1
plt.tight_layout()

# %%
#Plotting all the Departments in one graph by using CrossTab
plt.figure(figsize=(20,10))
pd.crosstab(data.Sales_Agent,data.Status).plot(kind='bar')
plt.xlabel('Sales_Agent')
plt.title("Performance Rating for each Department")
plt.show()

# %%
plt.figure(figsize=(15,10))
a=sns.countplot(x='Product_ID',hue='Status',data=data)
plt.title('product and sales')
plt.show()

# %%
plt.figure(figsize=(30, 20))
sns.countplot(x='Location', hue='Status', data=data)
plt.title("location base graph")
plt.show()

# %%
plt.figure(figsize=(20,25)) 
plotnumber=1            
for column in data:  
    plt.subplot(4,4,plotnumber)
    sns.countplot(x=data[column], hue=data['Status'])
    
    plt.xlabel(column,fontsize=20)
    plt.ylabel('Staus',fontsize=20)
    plotnumber+=1 
    
plt.tight_layout()

# %%
plt.figure(figsize=(20,25)) 
plotnumber=1            
for column in data:  
    plt.subplot(4,4,plotnumber)
    sns.histplot(x=data[column], hue=data['Status'])
    
    plt.xlabel(column,fontsize=20)
    plt.ylabel('Staus',fontsize=20)
    plotnumber+=1 
    
plt.tight_layout()

# %% [markdown]
# # <font color='tomato'>multivariate Analysis:</font>

# %%
# multivariate analysisis
sns.pairplot(data=data)

# %%
data.corr()
# Out:
#                  Source  Sales_Agent  Location  Delivery_Mode    Status
# Source         1.000000    -0.012968 -0.044524      -0.240396  0.046305
# Sales_Agent   -0.012968     1.000000 -0.137314      -0.224688  0.055800
# Location      -0.044524    -0.137314  1.000000       0.409688 -0.305882
# Delivery_Mode -0.240396    -0.224688  0.409688       1.000000 -0.226831
# Status         0.046305     0.055800 -0.305882      -0.226831  1.000000

# %%
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#      Product_ID  Source  Sales_Agent  Location  Delivery_Mode  Status
# 0             9       5            4         0              0       1
# 1            19       0            5         7              4       1
# 2            18       4            1         9              0       1
# 3            15       4            8         4              0       0
# 4            18       0            8         0              0       1
# ...         ...     ...          ...       ...            ...     ...
# 7323          9       0            7         6              3       1
# 7324         15       0            2         7              4       1
# 7325          5       5            1         0              0       0
# 7326         21       3            5         7              0       1
# 7327         25       4            4         1              0       1
#
# [7328 rows x 6 columns]

# %% [markdown]
# Theri are no correlation between any feature we go to the model creation without drop any columns.

# %% [markdown]
# ## Spliting data into training and testing :-

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
print(x_train.shape,'\n',x_test.shape,'\n',y_train.shape,'\n',y_test.shape)
# Out:
# (5862, 5)
#  (1466, 5)
#  (5862,)
#  (1466,)

# %% [markdown]
# # <font color='tomato'>Logistic regrassion:</font>

# %% [markdown]
# - This is classification probluem

# %%
from sklearn.linear_model import LogisticRegression # IMPORTING PACKAGE
lr=LogisticRegression() # OBJECT CREATION 
lr.fit(x_train,y_train)
y_predict_lr=lr.predict(x_test)

# %%
from sklearn.metrics import f1_score,classification_report,accuracy_score,auc,precision_score,recall_score,r2_score
accuracy=accuracy_score(y_predict_lr,y_test)
accuracy
# Out:
# 0.7100954979536153

# %%
# Recall
Recall = recall_score(y_test,y_predict_lr)# the total number of positive results how many positives were correctly predicted by the model.
Recall
# Out:
# 0.8409331919406151

# %%
clss_rep=classification_report(y_test,y_predict_lr)
print(clss_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.47      0.54       523
#            1       0.74      0.84      0.79       943
#
#     accuracy                           0.71      1466
#    macro avg       0.68      0.66      0.66      1466
# weighted avg       0.70      0.71      0.70      1466

# %%
# Model evaluation

from sklearn import metrics

def evaluate_model(model, x_test, y_test):  #we create user define function
    
    y_pred = model.predict(x_test) 

    # Calculate accuracy, precision, recall, f1-score
    acc  = metrics.accuracy_score(y_test, y_pred)
    prec = metrics.precision_score(y_test, y_pred)
    rec  = metrics.recall_score(y_test, y_pred)
    f1   = metrics.f1_score(y_test, y_pred)

    # Display confussion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1, 'cm': cm}

# %%
# Evaluate Model
lr_eval = evaluate_model(lr,x_test, y_test)

print('Accuracy:',  lr_eval['acc'])
print('F1 Score:',  lr_eval['f1']) 
print('Precision:', lr_eval['prec'])
print('Recall:',    lr_eval['rec'])
print('Confusion Matrix:\n', lr_eval['cm'])
# Out:
# Accuracy: 0.7100954979536153
# F1 Score: 0.7886623570363004
# Precision: 0.7425093632958801
# Recall: 0.8409331919406151
# Confusion Matrix:
#  [[248 275]
#  [150 793]]

# %% [markdown]
# # <font color='tomato'>KNN:</font>

# %%
## Error calculation for regression task
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier

rmse_val = [] #create list to store rmse values for different k
for K in range(20):
    K = K+1
    model = KNeighborsRegressor(n_neighbors = K)

    model.fit(x_train, y_train)  #fit the model
    pred=model.predict(x_test) #make prediction on test set
    error = np.sqrt(mean_squared_error(y_test,pred)) #calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
# Out:
# RMSE value for k=  1 is: 0.6052295968792409
# RMSE value for k=  2 is: 0.5175962386869373
# RMSE value for k=  3 is: 0.49147653964895877
# RMSE value for k=  4 is: 0.4742247928577567
# RMSE value for k=  5 is: 0.4649810393822454
# RMSE value for k=  6 is: 0.45705773544862394
# RMSE value for k=  7 is: 0.45335352104095494
# RMSE value for k=  8 is: 0.450043104650717
# RMSE value for k=  9 is: 0.4448800351411855
# RMSE value for k=  10 is: 0.4403118081585139
# RMSE value for k=  11 is: 0.438588832177448
# RMSE value for k=  12 is: 0.43731250990254716
# RMSE value for k=  13 is: 0.4353837365340795
# RMSE value for k=  14 is: 0.433163374755545
# RMSE value for k=  15 is: 0.4325157572257892
# RMSE value for k=  16 is: 0.4316629717895528
# RMSE value for k=  17 is: 0.4310927978890516
# RMSE value for k=  18 is: 0.43115993950784726
# RMSE value for k=  19 is: 0.42834039107017896
# RMSE value for k=  20 is: 0.4280476156400313

# %%
## taking optimal k to determine how many nearest neighbors  to create

# create a list to store the error values for each k
error_rate = []

# Will take some time
for i in range(1,11):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train,y_train)
    pred_i = knn.predict(x_test)
    error_rate.append(np.mean(pred_i != y_test))

# %%
# Lets plot the k-value and error rate

plt.figure(figsize=(10,6))
plt.plot(range(1,11),error_rate,color='blue', linestyle='dashed', 
         marker='o',markerfacecolor='red', markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
# let's fit the data into KNN model and see how well it performs:
knn = KNeighborsClassifier(n_neighbors=8)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
# Predict 
y_pred = knn.predict(x_test)

# %%
# Checking Accuracy score
print("The accuracy score is : ", accuracy_score(y_test,y_pred))
# Out:
# The accuracy score is :  0.6978171896316507

# %%
clas_re=classification_report(y_test,y_pred)

# %%
print(clas_re)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.58      0.56      0.57       523
#            1       0.76      0.77      0.77       943
#
#     accuracy                           0.70      1466
#    macro avg       0.67      0.67      0.67      1466
# weighted avg       0.70      0.70      0.70      1466

# %%
# Model evaluation

from sklearn import metrics

def evaluate_model(model, x_test, y_test):  #we create user define function
    
    y_pred = model.predict(x_test) 

    # Calculate accuracy, precision, recall, f1-score
    acc  = metrics.accuracy_score(y_test, y_pred)
    prec = metrics.precision_score(y_test, y_pred)
    rec  = metrics.recall_score(y_test, y_pred)
    f1   = metrics.f1_score(y_test, y_pred)

    # Display confussion matrix
    cm = metrics.confusion_matrix(y_test, y_pred)
    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1, 'cm': cm}

# %%
# Evaluate Model
knn_eval = evaluate_model(knn,x_test, y_test)

print('Accuracy:',  knn_eval['acc'])
print('F1 Score:',  knn_eval['f1']) 
print('Precision:', knn_eval['prec'])
print('Recall:',    knn_eval['rec'])
print('Confusion Matrix:\n', knn_eval['cm'])
# Out:
# Accuracy: 0.6978171896316507
# F1 Score: 0.766964755391899
# Precision: 0.7609603340292276
# Recall: 0.7730646871686108
# Confusion Matrix:
#  [[294 229]
#  [214 729]]

# %% [markdown]
# # <font color='tomato'>Decision Tree:</font>

# %%
from sklearn.tree import DecisionTreeClassifier#importing decision tree from sklearn.tree
dt=DecisionTreeClassifier()#object creation for decision tree  
dt.fit(x_train,y_train)#training the model
y_hat=dt.predict(x_test)#prediction
y_hat#predicted values
# Out:
# array([1, 1, 0, ..., 1, 1, 0], dtype=int64)

# %%
y_train_predict=dt.predict(x_train)#predicting training data to check training performance 
y_train_predict
# Out:
# array([0, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
##Training score
acc_train=accuracy_score(y_train,y_train_predict)#checking accuracy
acc_train
# Out:
# 0.8403275332650972

# %%
print(classification_report(y_train,y_train_predict))# it will give precision,recall,f1 scores and accuracy
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.77      0.78      2128
#            1       0.87      0.88      0.88      3734
#
#     accuracy                           0.84      5862
#    macro avg       0.83      0.83      0.83      5862
# weighted avg       0.84      0.84      0.84      5862

# %%
pd.crosstab(y_train,y_train_predict)#it will show you confusion matrix
# Out:
# col_0      0     1
# Status
# 0       1638   490
# 1        446  3288

# %%
## test acc
test_acc=accuracy_score(y_test,y_hat)#testing accuracy 
test_acc
# Out:
# 0.6869031377899045

# %%
## test score
test_f1=f1_score(y_test,y_hat, average='weighted')#f1 score
test_f1
# Out:
# 0.6881028657022634

# %%
print(classification_report(y_test,y_hat))# for  testing
# Out:
#               precision    recall  f1-score   support
#
#            0       0.56      0.58      0.57       523
#            1       0.76      0.75      0.75       943
#
#     accuracy                           0.69      1466
#    macro avg       0.66      0.66      0.66      1466
# weighted avg       0.69      0.69      0.69      1466

# %%
pd.crosstab(y_test,y_hat)# confusion matrix for
# Out:
# col_0     0    1
# Status
# 0       303  220
# 1       239  704

# %%
# Decision Tree Evaluation:

dt_eval = evaluate_model(dt, x_test, y_test)

print('Accuracy:', dt_eval['acc'])
print('Precision:', dt_eval['prec'])
print('Recall:', dt_eval['rec'])
print('F1 Score:', dt_eval['f1'])
print('Confusion Matrix : \n' , dt_eval['cm'])
# Out:
# Accuracy: 0.6869031377899045
# Precision: 0.7619047619047619
# Recall: 0.7465535524920467
# F1 Score: 0.754151044456347
# Confusion Matrix :
#  [[303 220]
#  [239 704]]

# %%
from sklearn.model_selection import GridSearchCV
#It helps to loop through predefined hyperparameters and fit your estimator (model) on your training set. 
#So,in the end, you can select the best parameters from the listed hyperparameters.

# %%
#creating dictionary--> key value pair of hyperparameters having key as parameter and values as its values
params = {
    "criterion":("gini", "entropy"), #quality of split
    "splitter":("best", "random"), # searches the features for a split
    "max_depth":(list(range(1, 20))), #depth of tree range from 1 to 19
    "min_samples_split":[2, 3, 4],    #the minimum number of samples required to split internal node
    "min_samples_leaf":list(range(1, 20)),#minimum number of samples required to be at a leaf node,we are passing list which is range from 1 to 19 
}


tree_clf = DecisionTreeClassifier(random_state=3)#object creation for decision tree with random state 3
tree_cv = GridSearchCV(tree_clf, params, scoring="f1", n_jobs=-1, verbose=1, cv=3)
#passing model to gridsearchCV ,
#tree_clf-->model
#params---->hyperparametes(dictionary we created)
#scoring--->performance matrix to check performance
#n_jobs---->Number of jobs to run in parallel,-1 means using all processors.
#verbose=Controls the verbosity: the higher, the more messages.
#>1 : the computation time for each fold and parameter candidate is displayed;
#>2 : the score is also displayed;
#>3 : the fold and candidate parameter indexes are also displayed together with the starting time of the computation.
#cv------> number of flods




tree_cv.fit(x_train,y_train)#training data on gridsearch cv
best_params = tree_cv.best_params_#it will give you best parameters 
print(f"Best paramters: {best_params})")#printing  best parameters
# Out:
# Fitting 3 folds for each of 4332 candidates, totalling 12996 fits
# Best paramters: {'criterion': 'entropy', 'max_depth': 6, 'min_samples_leaf': 12, 'min_samples_split': 2, 'splitter': 'best'})

# %%
tree_cv.best_score_#getting best score form cv
# Out:
# 0.8153625064470266

# %%
dt1=DecisionTreeClassifier(criterion= "gini", max_depth= 5, min_samples_leaf =13, min_samples_split= 2, splitter="best")#passing best parameter to decision tree

# %%
dt1.fit(x_train,y_train)#traing model with best parameter
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=13)

# %%
y_hat1=dt1.predict(x_test)#predicting
y_hat1
# Out:
# array([0, 0, 0, ..., 0, 1, 1], dtype=int64)

# %%
acc_test=accuracy_score(y_test,y_hat1)#checking accuracy
acc_test
# Out:
# 0.7530695770804912

# %%
test_f1=f1_score(y_test,y_hat1)#f1_score
test_f1
# Out:
# 0.8235867446393762

# %% [markdown]
# # <font color='tomato'>Random forest:</font>

# %%
from sklearn.ensemble import RandomForestClassifier#importing randomforest

rf_clf = RandomForestClassifier(n_estimators=100)#object creation ,taking 100 decision tree in random forest 
rf_clf.fit(x_train,y_train)#training the data
# Out:
# RandomForestClassifier()

# %%
rf_clf_pred=rf_clf.predict(x_test)

# %%
cls_rep=classification_report(rf_clf_pred,y_test)

# %%
print(cls_rep)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.53      0.60      0.56       460
#            1       0.80      0.75      0.78      1006
#
#     accuracy                           0.71      1466
#    macro avg       0.67      0.68      0.67      1466
# weighted avg       0.72      0.71      0.71      1466

# %%
#  Evaluation model:

rf_clf_eval = evaluate_model(rf_clf, x_test, y_test)

print('Accuracy:', rf_clf_eval['acc'])
print('Precision:', rf_clf_eval['prec'])
print('Recall:', rf_clf_eval['rec'])
print('F1 Score:', rf_clf_eval['f1'])
print('Confusion Matrix : \n' , rf_clf_eval['cm'])
# Out:
# Accuracy: 0.7060027285129604
# Precision: 0.7544731610337972
# Recall: 0.8048780487804879
# F1 Score: 0.7788609543355568
# Confusion Matrix :
#  [[276 247]
#  [184 759]]

# %% [markdown]
# # <font color='tomato'>support vector machine :</font>

# %%
# Support Vector Classifier Model

from sklearn.svm import SVC
svclassifier = SVC() ## base model with default parameters
svclassifier.fit(x_train, y_train)
# Out:
# SVC()

# %%
# Predict output for X_test

y_hat=svclassifier.predict(x_test)

# %%
acc=accuracy_score(y_test,y_hat)
acc
# Out:
# 0.732605729877217

# %%
print(classification_report(y_test,y_hat))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.40      0.51       523
#            1       0.73      0.92      0.82       943
#
#     accuracy                           0.73      1466
#    macro avg       0.73      0.66      0.66      1466
# weighted avg       0.73      0.73      0.71      1466

# %%
cm1=pd.crosstab(y_test,y_hat)
cm1
# Out:
# col_0     0    1
# Status
# 0       207  316
# 1        76  867

# %%
# F1 score considers both Precision and Recall for evaluating a model
f1=f1_score(y_test,y_hat)
f1
# Out:
# 0.8156161806208841

# %%
## checking cross validation score
from sklearn.model_selection import cross_val_score
scores = cross_val_score(svclassifier,x,y,cv=3,scoring='f1')
print(scores)
print("Cross validation Score:",scores.mean())
print("Std :",scores.std())
#std of < 0.05 is good.
# Out:
# [0.79781106 0.81851958 0.80372807]
# Cross validation Score: 0.8066862357017598
# Std : 0.008709141853165034

# %%
#  Evaluation:

svclassifier_eval = evaluate_model(svclassifier, x_test, y_test)

print('Accuracy:', svclassifier_eval['acc'])
print('Precision:', svclassifier_eval['prec'])
print('Recall:', svclassifier_eval['rec'])
print('F1 Score:', svclassifier_eval['f1'])
print('Confusion Matrix : \n' ,svclassifier_eval['cm'])
# Out:
# Accuracy: 0.732605729877217
# Precision: 0.7328825021132713
# Recall: 0.9194061505832449
# F1 Score: 0.8156161806208841
# Confusion Matrix :
#  [[207 316]
#  [ 76 867]]

# %%
column_labels = ['Classifier','Accuracy','Recall','Precision','F1-score']

# Decision tree 
df1= pd.DataFrame([[ 'DecisionTree',  dt_eval['acc'], dt_eval['rec'], dt_eval['prec'], dt_eval['f1'] ]], columns = column_labels )
                 
# Random forest
df2 = pd.DataFrame([[ 'RandomForest',rf_clf_eval['acc'], rf_clf_eval['rec'], rf_clf_eval['prec'], rf_clf_eval['f1'] ]] , columns = column_labels )


# logistic regression 
df3 = pd.DataFrame([[ 'LogisticRegression', lr_eval['acc'], lr_eval['rec'], lr_eval['prec'], lr_eval['f1'] ]], columns = column_labels )


# KNN 
df4 = pd.DataFrame([[ 'KNN', knn_eval['acc'],  knn_eval['rec'], knn_eval['prec'], knn_eval['f1'] ]], columns = column_labels )

# SVM 
df5 = pd.DataFrame([[ 'SupportVectorMachine',  svclassifier_eval['acc'], svclassifier_eval['rec'], svclassifier_eval['prec'], svclassifier_eval['f1'] ]], columns = column_labels )

# %% [markdown]
# ## All Algorithum Evaluvation in one column

# %%
combined_data= pd.concat([df1, df2, df3, df4, df5], axis=0)
combined_data
# Out:
#              Classifier  Accuracy    Recall  Precision  F1-score
# 0          DecisionTree  0.686903  0.746554   0.761905  0.754151
# 0          RandomForest  0.706003  0.804878   0.754473  0.778861
# 0    LogisticRegression  0.710095  0.840933   0.742509  0.788662
# 0                   KNN  0.697817  0.773065   0.760960  0.766965
# 0  SupportVectorMachine  0.732606  0.919406   0.732883  0.815616
